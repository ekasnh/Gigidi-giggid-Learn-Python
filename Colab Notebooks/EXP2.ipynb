# %% [markdown]
# Ekansh Agarwal
# J001

# %% [markdown]
# Brute force attack using caesar cipher

# %%
##for encryption

Encrypt = input("Enter word to be encrypted: ")
key = int(input("Enter Key: "))
words = ["encryption"]
decrypt = ''
def ciphertext(Encrypt,key) : 
    for i in Encrypt:
      lower_char = i.lower()
      extract_value = ord(lower_char)-97
      decrypt_value = ((extract_value+key) % 26)+97
      decrypt += chr(decrypt_value)
    print(decrypt)

  ## for decryption (reverse cipher using transposition)   
def decrypting(decrypt): 
  for i in range(26):
    word = ''
    for j in range(len(decrypt)):
        extract = ord(decrypt[j])-97
        decrypt_value = ((extract-i) % 26)+97
        word += chr(decrypt_value)
            
    if word in words:
        print("Decrypted Word is:", word)
        print("The Key is:", i)
        break
# Out:
# Enter word to be encrypted: sss
# Enter Key: 55

# %% [markdown]
# Subsitution cipher

# %%
def printString(S, N):
	plaintext = [None] * 5
	freq = [0] * 26
	freqSorted = [None] * 26
	
	# Store which alphabet is used already
	used = [0] * 26
	
	# Traverse the string S
	for i in range(N):
		if S[i] != ' ':
			freq[ord(S[i]) - 65] += 1
			
	# Copy the frequency array		
	for i in range(26):
		freqSorted[i] = freq[i]

	T = "ETAOINSHRDLCUMWFGYPBVKJXQZ"
	
	# Sort the array in descending order
	freqSorted.sort(reverse = True)
	
	# Iterate over the range [0, 5]
	for i in range(5):
		ch = -1
		
		# Iterate over the range [0, 26]
		for j in range(26):
			if freqSorted[i] == freq[j] and used[j] == 0:
				used[j] = 1
				ch = j
				break
			
		if ch == -1:
			break
		
		# Store the numerical equivalent of letter
		# at ith index of array letter_frequency
		x = ord(T[i]) - 65
		
		# Calculate the probable shift used
		# in monoalphabetic cipher
		x = x - ch
		
		# Temporary string to generate one
		# plaintext at a time
		curr = ""
		
		# Generate the probable ith plaintext
		# string using the shift calculated above
		for k in range(N):
			
			# Insert whitespaces as it is
			if S[k] == ' ':
				curr += " "
				continue
			
			# Shift the kth letter of the
			# cipher by x
			y = ord(S[k]) - 65
			y += x
			
			if y < 0:
				y += 26
			if y > 25:
				y -= 26
			
			# Add the kth calculated/shifted
			# letter to temporary string	
			curr += chr(y + 65)
			
		plaintext[i] = curr
	
	# Print the generated 5 possible plaintexts	
	for i in range(5):
		print(plaintext[i])

# Driver code

# Given string
S = "B TJNQMF NFTTBHF"
N = len(S)

# Function Call
printString(S, N)
