# %% [markdown]
# SVKM’s NMIMS University Mukesh Patel School of Technology Management & Engineering <br>
# **COURSE: Data Encryption and Network Security**

# %% [markdown]
# **Name**: Ekansh Agarwal <BR>
# **Roll No.**: J001 <BR>
# **Semester/Program**: VIII / MBA.Tech(EXTC)<BR>

# %% [markdown]
# ##**EXPERIMENT 5**
# ###**Aim**  -
#
# a. To obtain multiplicative inverse of a number using extended Euclidean theorem
#
# b. To implement Chinese Remainder theorem

# %% [markdown]
# ###Euclidean Algorithm

# %%
#gcd function or euclidean algorithim
def gcd(a,b):
  if a == 0:
    return b
  return gcd(b%a, a)

# %%
a = int(input("Enter the 1st number: "))
b = int(input("Enter the 2nd number: "))
#gcd(a,b)
print("Gcd of the two number is : ", end="")
print(gcd(a,b))
# Out:
# Enter the 1st number: 11
# Enter the 2nd number: 77
# Gcd of the two number is : 11

# %% [markdown]
# ###Extended Euclidean Algorithm

# %%
#user input
a = int(input("Enter the 1st number: "))
b = int(input("Enter the 2nd number: "))
# Out:
# Enter the 1st number: 161
# Enter the 2nd number: 28

# %%
#function for extended eculidean
def euclidean_extended(a,b):
  #initialization 
  r1=a
  r2=b
  s1= int(1)
  s2= int(0)
  t1= int(0)
  t2= int(1)
  #steps in extended exulideab algorithim 
  while r2>0:
    q= r1//r2
    r= r1-q*r2
    r1= r2
    r2 = r
    s= s1-q*s2
    s1=s2
    s2=s
    t= t1-q*t2
    t1=t2
    t2=t
  if(t1<0):
    t1= t1%a
  else: t1=1
  return (r1,t1)

# %% [markdown]
# ####CRT

# %%
#Chinese Remainder theorem

m1,m2,m3= input("Enter m1,m2,m3").split()
m1= int(m1)
m2=int(m2)
m3=int(m3)
a1,a2,a3= input("Enter a1,a2,a3").split()
a1= int(a1)
a2=int(a2)
a3=int(a3)
M= m1*m2*m3
M1= M/m1
M2=M/m2
M3=M/m3
M1gcd, M1inv= euclidean_extended(m1,M1)
print(M1inv)
M2gcd, M2inv= euclidean_extended(m2,M2)
print(M2inv)
M3gcd, M3inv= euclidean_extended(m3,M3)
print(M3inv)
temp= a1*M1*M1inv + a2*M2*M2inv +a3*M3*M3inv
print(temp)
x= temp%M
print("Solution to the given simultaneous equation is ",x)
# Out:
# Enter m1,m2,m311 12 13
# Enter a1,a2,a321 30 98
# 6.0
# 11.0
# 7.0
# 157398.0
# Solution to the given simultaneous equation is  1242.0

# %% [markdown]
# ##**Conclusion:**
# In this experiment we have implemented Chinese Remainder Theorem (CRT) using Extended Eculidean algorithm. We have written the code for Extended Eculidean algorithm which helps find the multiplicative inverse of a given number. CRT can be used for computing with large integers.
