# %% [markdown]
# # **Experiment 7**
#
# ### **Name:** Ekansh Agarwal
#
# ### **Roll No.:** J001

# %% [markdown]
# ### **Aim:**
#
# a.	To implement Diffie Hellman key exchange algorithm
#
# b.	To implement Diffie Hellman key exchange algorithm Man-in-Middle or Bucket Brigade Attack

# %% [markdown]
# a.

# %%
from random import randint

# %%
# Both the persons will be agreed upon the public keys G and P
# A prime number P is taken
P = 19
	
# A primitive root for P, G is taken
G = 2

# %%
print('The Value of Alice is :%d'%(P))
print('The Value of Bob is :%d'%(G))
# Out:
# The Value of Alice is :19
# The Value of Bob is :2

# %%
# Alice will choose the private key a
a = 4
print('The Private Key a for Alice is :%d'%(a))
# Out:
# The Private Key a for Alice is :4

# %%
# gets the generated key
x = int(pow(G,a,P))

# %%
# Bob will choose the private key b
b = 3
print('The Private Key b for Bob is :%d'%(b))
# Out:
# The Private Key b for Bob is :3

# %%
# gets the generated key
y = int(pow(G,b,P))

# %%
# Secret key for Alice
ka = int(pow(y,a,P))

# %%
# Secret key for Bob
kb = int(pow(x,b,P))

# %%
print('Secret key for the Alice is : %d'%(ka))
print('Secret Key for the Bob is : %d'%(kb))
# Out:
# Secret key for the Alice is : 11
# Secret Key for the Bob is : 11

# %% [markdown]
# b.

# %%
import random

# %%
# public keys are taken
# p is a prime number
# g is a primitive root of p
p = int(input('Enter a prime number : '))
g = int(input('Enter a number : '))
# Out:
# Enter a prime number : 19
# Enter a number : 2

# %%
class A:
	def __init__(self):
		# Generating a random private number selected by alice
		self.n = random.randint(1, p)	

	def publish(self):
		# generating public values
		return (g**self.n)%p

	def compute_secret(self, gb):
		# computing secret key
		return (gb**self.n)%p

# %%
class B:
	def __init__(self):
		# Generating a random private number selected for alice
		self.a = random.randint(1, p)
		# Generating a random private number selected for bob
		self.b = random.randint(1, p)
		self.arr = [self.a,self.b]

	def publish(self, i):
		# generating public values
		return (g**self.arr[i])%p

	def compute_secret(self, ga, i):
		# computing secret key
		return (ga**self.arr[i])%p

# %%
alice = A()
bob = A()
eve = B()

# %%
# Printing out the private selected number by Alice and Bob
print(f'Alice selected (a) : {alice.n}')
print(f'Bob selected (b) : {bob.n}')
print(f'Eve selected private number for Alice (c) : {eve.a}')
print(f'Eve selected private number for Bob (d) : {eve.b}')
# Out:
# Alice selected (a) : 16
# Bob selected (b) : 16
# Eve selected private number for Alice (c) : 12
# Eve selected private number for Bob (d) : 1

# %%
# Generating public values
ga = alice.publish()
gb = bob.publish()
gea = eve.publish(0)
geb = eve.publish(1)
print(f'Alice published (ga): {ga}')
print(f'Bob published (gb): {gb}')
print(f'Eve published value for Alice (gc): {gea}')
print(f'Eve published value for Bob (gd): {geb}')
# Out:
# Alice published (ga): 5
# Bob published (gb): 5
# Eve published value for Alice (gc): 11
# Eve published value for Bob (gd): 2

# %%
# Computing the secret key
sa = alice.compute_secret(gea)
sea = eve.compute_secret(ga,0)
sb = bob.compute_secret(geb)
seb = eve.compute_secret(gb,1)
print(f'Alice computed (S1) : {sa}')
print(f'Eve computed key for Alice (S1) : {sea}')
print(f'Bob computed (S2) : {sb}')
print(f'Eve computed key for Bob (S2) : {seb}')
# Out:
# Alice computed (S1) : 11
# Eve computed key for Alice (S1) : 11
# Bob computed (S2) : 5
# Eve computed key for Bob (S2) : 5

# %% [markdown]
# ### **Conclusion:**
#
# In this experiment, I implemented Diffie Hellman key exchange algorithm and also performed Man-in-Middle or Bucket Brigade Attack on it. Serect key of both people were matching before but after I performed Man-in-Middle serect key of both were not matching.
