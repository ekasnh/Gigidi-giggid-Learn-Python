# %% [markdown]
# This notebook presents an MNIST digit classifier built with a fully-connected neural network in TensorFlow and Keras.

# %% [markdown]
# ## 1. Import Statements
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %tensorflow_version 2.x
import tensorflow as tf
import tensorflow.keras as tk
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# ## 2. Data Preprocessing
#
# ---

# %% [markdown]
# The first step is to preprocess our data. Here, we load the MNIST digit dataset from the Keras datasets library, split it into training and test sets, reshape the matrices, and encode the labels categorically.

# %%
# Load the MNIST dataset.
mnist = tf.keras.datasets.mnist
train_data, test_data = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
# Divide the data into features and labels.
train_images, train_labels = tk.datasets.mnist.load_data()
test_images, test_labels = tk.datasets.mnist.load_data()

# (x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Reshape and normalize the images.
X_train = train_images.reshape(train_images.shape[0], 28, 28, 1)
X_train = X_train.astype('float32') / 255.0
X_test = test_images.reshape((60000,28,28,1))
X_test = X_test.astype('float32') / 255
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-d864fff1fd30> in <cell line: 2>()
#       1 # Reshape and normalize the images.
# ----> 2 X_train = train_images.reshape(train_images.shape[0], 28, 28, 1)
#       3 X_train = X_train.astype('float32') / 255.0
#       4 X_test = test_images.reshape((60000,28,28,1))
#       5 X_test = X_test.astype('float32') / 255
#
# AttributeError: 'tuple' object has no attribute 'reshape'

# %%
# Reshape the labels and encode them categorically.
y_train = tf.keras.utils.to_categorical(test_images)
y_test = tf.keras.utils.to_categorical(test_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-c504e2cbea6d> in <cell line: 2>()
#       1 # Reshape the labels and encode them categorically.
# ----> 2 y_train = tf.keras.utils.to_categorical(test_images)
#       3 y_test = tf.keras.utils.to_categorical(test_labels)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      60     [0. 0. 0. 0.]
#      61     """
# ---> 62     y = np.array(y, dtype="int")
#      63     input_shape = y.shape
#      64
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 60000) + inhomogeneous part.

# %% [markdown]
# Further, the following are the shapes of each matrix, as well as a visualization of a random MNIST digit.

# %%
# Show the shapes of the data.
print("Training Images:",X_train )
print("Testing Images:",X_test )
print("Training Labels:",y_train )
print("Test Labels:", y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4dbbb7a35d18> in <cell line: 2>()
#       1 # Show the shapes of the data.
# ----> 2 print("Training Images:",X_train )
#       3 print("Testing Images:",X_test )
#       4 print("Training Labels:",y_train )
#       5 print("Test Labels:", y_test)
#
# NameError: name 'X_train' is not defined

# %%
# Show a sample MNIST digit.
plt.imshow(train_images[1])
# plt.title("Digit Label: %d" % train_df['label'].iloc[x])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-df1673114d36> in <cell line: 2>()
#       1 # Show a sample MNIST digit.
# ----> 2 plt.imshow(train_images[1])
#       3 # plt.title("Digit Label: %d" % train_df['label'].iloc[x])
#       4
#       5 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5663                               **kwargs)
#    5664
# -> 5665         im.set_data(X)
#    5666         im.set_alpha(alpha)
#    5667         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/image.py in set_data(self, A)
#     708         if not (self._A.ndim == 2
#     709                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 710             raise TypeError("Invalid shape {} for image data"
#     711                             .format(self._A.shape))
#     712
#
# TypeError: Invalid shape (60000,) for image data

# %% [markdown]
# ## 3. Neural Network
#
# ---

# %% [markdown]
# ### 3.1. Define the Model

# %% [markdown]
# We then have to define our neural network. Here, we define a sequential model with two fully-connected layers.

# %%
# Define the sequential model.
model = tf.keras.models.Sequential()
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-a5217a003306> in <cell line: 3>()
#       1 # Define the sequential model.
#       2 model = tf.keras.models.Sequential()
# ----> 3 X_train.shape
#
# NameError: name 'X_train' is not defined

# %%
# Add two fully-connected layers to the network.
model.add(tf.keras.layers.Dense(64, activation='relu',input_shape=(784,784)))
model.add(tf.keras.layers.Dense(32, activation='softmax'))

# %%
# Show the model.
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-6708e5f00180> in <cell line: 2>()
#       1 # Show the model.
# ----> 2 model.summary()
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in summary(self, line_length, positions, print_fn, expand_nested, show_trainable, layer_range)
#    3227         """
#    3228         if not self.built:
# -> 3229             raise ValueError(
#    3230                 "This model has not yet been built. "
#    3231                 "Build the model first by calling `build()` or by calling "
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.

# %% [markdown]
# Once our model is defined, we can compile it using the Adam optimizer and the categorical cross-entropy loss function.

# %%
# Compile the model.
# model.add(Dense(5, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### 3.2. Train the Model

# %% [markdown]
# We then train the model on 10 epochs, using a batch size of 256.

# %%
# Define the parameters.
num_epochs = 10
batch_size = 256

# Train the model.
history = model.fit(X_train,Y_train,epochs=num_epochs,batch_size=batch_size,validation_data=(x_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-3dcf4a09a6b5> in <cell line: 6>()
#       4
#       5 # Train the model.
# ----> 6 history = model.fit(X_train,Y_train,epochs=num_epochs,batch_size=batch_size,validation_data=(x_test,y_test))
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### 3.3. Display the Metrics

# %% [markdown]
# Finally, we display the metrics. We begin by displaying the model's accuracy and loss based on the test set.

# %%
test_loss, test_accuracy = model.evaluate()
print('Test Accuracy:', test_accuracy)
print('Test Loss:', test_loss)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-db4f5a35da68> in <cell line: 1>()
# ----> 1 test_loss, test_accuracy = model.evaluate()
#       2 print('Test Accuracy:', test_accuracy)
#       3 print('Test Loss:', test_loss)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in _assert_compile_was_called(self)
#    3683         # (i.e. whether the model is built and its inputs/outputs are set).
#    3684         if not self._is_compiled:
# -> 3685             raise RuntimeError(
#    3686                 "You must compile your model before "
#    3687                 "training/testing. "
#
# RuntimeError: You must compile your model before training/testing. Use `model.compile(optimizer, loss)`.

# %% [markdown]
# Then, we save the metric values for each epoch to plot the loss and accuracy curves for our model.

# %%
# Save the metrics.
metrics = history.history
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1847ffaf5c0a> in <cell line: 2>()
#       1 # Save the metrics.
# ----> 2 metrics = history.history
#
# NameError: name 'history' is not defined

# %% [markdown]
# Finally, once we have our metric history, we can plot the curves.

# %%
# Save the loss values.
training_loss_list = metrics['loss']
test_loss_list = metrics['val_loss']

# %%
# Plot the training and test loss.
x = np.arange(0, num_epochs, 1)
plt.title('Training and Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(x, training_loss_list, label='Training Loss')
plt.plot(x, test_loss_list, label='Test Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-9a268195e55d> in <cell line: 2>()
#       1 # Plot the training and test loss.
# ----> 2 x = np.arange(0, num_epochs, 1)
#       3 plt.title('Training and Test Loss')
#       4 plt.xlabel('Epoch')
#       5 plt.ylabel('Loss')
#
# NameError: name 'num_epochs' is not defined

# %%
train_accuracy_list = metrics['accuracy']
test_accuracy_list = metrics['val_accuracy']

# %%
plt.title('Training and Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(x, train_accuracy_list, label='Training Accuracy')
plt.plot(x, test_accuracy_list, label='Test Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-90d340695fed> in <cell line: 4>()
#       2 plt.xlabel('Epoch')
#       3 plt.ylabel('Accuracy')
# ----> 4 plt.plot(x, train_accuracy_list, label='Training Accuracy')
#       5 plt.plot(x, test_accuracy_list, label='Test Accuracy')
#       6 plt.legend()
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## 4. Make a Prediction
#
# ---

# %% [markdown]
# Once our model is trained, we can use it to make predictions. To do this, we first use our test set to predict the classes.

# %%
# Make predictions with the trained model.
predictions = model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-e905f9d8c35d> in <cell line: 2>()
#       1 # Make predictions with the trained model.
# ----> 2 predictions = model.predict()
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: predict() missing 1 required positional argument: 'x'

# %% [markdown]
# Finally, we can show a random test image with its corresponding prediction.

# %%
# Choose an index.
index = 2

# Show an image from the test set.
plt.imshow(test_images[index])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-7cc58c12eca8> in <cell line: 5>()
#       3
#       4 # Show an image from the test set.
# ----> 5 plt.imshow(test_images[index])
#       6 plt.show()
#
# IndexError: tuple index out of range

# %%
print("Prediction:", np.argmax(predictions[]))
# Out:
# Prediction: 5
