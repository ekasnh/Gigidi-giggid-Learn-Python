# %% [markdown]
# SVKM’s NMIMS University Mukesh Patel School of Technology Management & Engineering <br>
# **COURSE: Data Encryption and Network Security**

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **Name: Ekansh Agarwal**
#
# **Class: MBATech EXTC Sem 8**
#
# **Roll No: J001**
#
# **Experiment 2**
#
# **AIM:**
#
# **a.	To implement Cryptanalysis on traditional cipher**

# %% [markdown]
# **Importing Libraries**

# %%
import string

# %% [markdown]
# **Creating 3 variables**

# %%
ALPHABET = string.ascii_lowercase
ALPHABET_LENGTH = len(ALPHABET)
ALPHABET_LENGTH_NEGATIVE = - ALPHABET_LENGTH

# %% [markdown]
# **Creating a function that can encrypt the text taken by the user**

# %%
def encrypt(plaintext, encryption_key):
    """Encrypt cipher text."""
    encrypted_letters = []
    for letter in plaintext:
        if letter not in ALPHABET:
            encrypted_letters.append(letter)
        elif letter in ALPHABET:
            plain_letter_index = ALPHABET.index(letter)
            encrypted_letter_index = plain_letter_index + encryption_key
            try:
                encrypted_letters.append(ALPHABET[encrypted_letter_index])
            except IndexError:
                index_difference = ALPHABET_LENGTH - plain_letter_index
                index_check = index_difference - encryption_key
                while ALPHABET_LENGTH <= index_check or index_check < 0:
                    if index_check < 0:
                        index_check = (index_check*-1)
                    if index_check >= ALPHABET_LENGTH:
                        index_check = index_check - ALPHABET_LENGTH
                    if index_check == ALPHABET_LENGTH:
                        index_check = 0
                encrypted_letters.append(ALPHABET[index_check])
    encrypted_message = ''.join(encrypted_letters)
    return encrypted_message

# %% [markdown]
# **Implementation of the encryption function**

# %%
secret_message = "Weather is good today"
secret_message_secured = encrypt(secret_message, 18)
print(secret_message_secured)
# Out:
# Wwslzwj ak yggv lgvsq

# %% [markdown]
# **Creating a function that can decrypt the encrypted text taken from the user**

# %%
def decrypt(ciphertext, encryption_key):
    """Decrypt ciphertext."""
    decrypted_letters = []
    for letter in ciphertext:
        if letter not in ALPHABET:
            decrypted_letters.append(letter)
        elif letter in ALPHABET:
            plain_letter_index = ALPHABET.index(letter)
            decrypted_letter_index = plain_letter_index - encryption_key
            if decrypted_letter_index >= 0:
                decrypted_letters.append(ALPHABET[decrypted_letter_index])
            else:
                try:
                    decrypted_letter_index += ALPHABET_LENGTH
                    decrypted_letters.append(ALPHABET[decrypted_letter_index])
                except IndexError:
                        while decrypted_letter_index <= ALPHABET_LENGTH_NEGATIVE:
                            decrypted_letter_index = decrypted_letter_index + ALPHABET_LENGTH
                        decrypted_letters.append(ALPHABET[decrypted_letter_index])
    decrypted_message = ''.join(decrypted_letters)
    return decrypted_message

# %% [markdown]
# **Implementation of the decryption cipher**

# %%
ciphertext_to_decipher = "Wwslzwj ak yggv lgvsq"
deciphered_text = decrypt(ciphertext_to_decipher, 18)
print(deciphered_text)
# Out:
# Weather is good today

# %% [markdown]
# **Creating a function that uses brute force algorithm to decrypt the message by using a range of possible keys**

# %%
def brute_force(ciphertext, possible_keys=ALPHABET_LENGTH):
  """Print possible plaintext for the provided ciphertext."""
  for possible_key in range(1, possible_keys):
    possible_text = decrypt(ciphertext, possible_key)
    print(f"Encryption key: {possible_key} - Plain text: {possible_text}")

# %% [markdown]
# **Implementation of the brute force algorithm function**

# %%
secret_message = "Wwslzwj ak yggv lgvsq"
brute_force(secret_message)
# Out:
# Encryption key: 1 - Plain text: Wvrkyvi zj xffu kfurp
# Encryption key: 2 - Plain text: Wuqjxuh yi weet jetqo
# Encryption key: 3 - Plain text: Wtpiwtg xh vdds idspn
# Encryption key: 4 - Plain text: Wsohvsf wg uccr hcrom
# Encryption key: 5 - Plain text: Wrngure vf tbbq gbqnl
# Encryption key: 6 - Plain text: Wqmftqd ue saap fapmk
# Encryption key: 7 - Plain text: Wplespc td rzzo ezolj
# Encryption key: 8 - Plain text: Wokdrob sc qyyn dynki
# Encryption key: 9 - Plain text: Wnjcqna rb pxxm cxmjh
# Encryption key: 10 - Plain text: Wmibpmz qa owwl bwlig
# Encryption key: 11 - Plain text: Wlhaoly pz nvvk avkhf
# Encryption key: 12 - Plain text: Wkgznkx oy muuj zujge
# Encryption key: 13 - Plain text: Wjfymjw nx ltti ytifd
# Encryption key: 14 - Plain text: Wiexliv mw kssh xshec
# Encryption key: 15 - Plain text: Whdwkhu lv jrrg wrgdb
# Encryption key: 16 - Plain text: Wgcvjgt ku iqqf vqfca
# Encryption key: 17 - Plain text: Wfbuifs jt hppe upebz
# Encryption key: 18 - Plain text: Weather is good today
# Encryption key: 19 - Plain text: Wdzsgdq hr fnnc snczx
# Encryption key: 20 - Plain text: Wcyrfcp gq emmb rmbyw
# Encryption key: 21 - Plain text: Wbxqebo fp dlla qlaxv
# Encryption key: 22 - Plain text: Wawpdan eo ckkz pkzwu
# Encryption key: 23 - Plain text: Wzvoczm dn bjjy ojyvt
# Encryption key: 24 - Plain text: Wyunbyl cm aiix nixus
# Encryption key: 25 - Plain text: Wxtmaxk bl zhhw mhwtr

# %% [markdown]
# **Conclusion**
# * We understood the concept and implementation of traditional cipher by creating functions that could encrypt and decrypt the text given by user.
# * Further, we understood the attacks that could occur on a traditional cipher by creating a function that could  find the key and decrypt the text given by user using brute force algorithm.
