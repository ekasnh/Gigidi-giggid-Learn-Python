# %% [markdown]
# XOR operator

# %%
a = 10
b = 4
c = 1


variables1= [1,0]
variables2= [0,1]
weights = [1,2,3]



# Print AND operation
print("a & b =", a & b)
z = weights[0]+ weights[1]*variables1[0]+ weights[2]*variables2[0]
print("z=",z)

# Print OR operation
print("a | b =", a | b)


#print xnor operation




# Print NOT operation
print("~a =", ~a)
#print("z value is",w1 + w2a + w3b)

# print XOR operation
print("a ^ b =", a ^ b)
#print("z value is",w1 + w2a + w3b)
# Out:
# a & b = 0
# z= 3
# a | b = 14
# ~a = -11
# a ^ b = 14
